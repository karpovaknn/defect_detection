# %% [markdown]
# # All

# %%
#all
# !python ../mmdetection/tools/test.py job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/job4_cascade_rcnn_x101_32x4d_fpn_1x_coco.py \
job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth --eval bbox --show #--out results/result.pkl
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [                                                  ] 0/178, elapsed: 0s, ETA:Figure(4608.01x3072.01)
# [                                 ] 1/178, 0.4 task/s, elapsed: 3s, ETA:   483sFigure(4608.01x3072.01)
# [                                 ] 2/178, 0.4 task/s, elapsed: 5s, ETA:   402sFigure(4608.01x3072.01)
# [                                 ] 3/178, 0.5 task/s, elapsed: 6s, ETA:   374sFigure(4608.01x3072.01)
# [                                 ] 4/178, 0.5 task/s, elapsed: 8s, ETA:   360sFigure(4608.01x3072.01)
# [                                ] 5/178, 0.5 task/s, elapsed: 10s, ETA:   349sFigure(4608.01x3072.01)
# [>                               ] 6/178, 0.5 task/s, elapsed: 12s, ETA:   345sFigure(4608.01x3072.01)
# ...

# %%
#all
# !python ../mmdetection/tools/test.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/job4_cascade_rcnn_x101_32x4d_fpn_1x_coco.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth \
       --format-only \
       --options "jsonfile_prefix=./results_all"
# Out:
# ../mmdetection/tools/test.py:115: UserWarning: --options is deprecated in favor of --eval-options
#   warnings.warn('--options is deprecated in favor of --eval-options')
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 178/178, 8.6 task/s, elapsed: 21s, ETA:     0s

# %%
#1600_4900
# !python tools/custom_coco_analysis.py \
        results_all.bbox.json \
        --ann dataset/test/coco.json \
        --areas 1600 4900 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.404
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = 0.829
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.749
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.059
# ...

# %%
#4900 9216
# !python tools/custom_coco_analysis.py \
        results_all.bbox.json \
        --ann dataset/test/coco.json \
        --areas 4900 9216 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.311
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = 0.826
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.371
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.749
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.500
# ...

# %% [markdown]
# # White

# %%
#white
# !python ../mmdetection/tools/test.py job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/white_test.py \
job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth --eval bbox --show
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [                                                  ] 0/103, elapsed: 0s, ETA:Figure(4608.01x3072.01)
# [                                 ] 1/103, 0.4 task/s, elapsed: 2s, ETA:   236sFigure(4608.01x3072.01)
# [                                 ] 2/103, 0.5 task/s, elapsed: 4s, ETA:   209sFigure(4608.01x3072.01)
# [                                 ] 3/103, 0.5 task/s, elapsed: 6s, ETA:   198sFigure(4608.01x3072.01)
# [>                                ] 4/103, 0.5 task/s, elapsed: 8s, ETA:   192sFigure(4608.01x3072.01)
# [>                               ] 5/103, 0.5 task/s, elapsed: 10s, ETA:   188sFigure(4608.01x3072.01)
# [>                               ] 6/103, 0.5 task/s, elapsed: 12s, ETA:   187sFigure(4608.01x3072.01)
# ...

# %%
# !python ../mmdetection/tools/test.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/white_test.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth \
       --format-only \
       --options "jsonfile_prefix=./results_white"
# Out:
# ../mmdetection/tools/test.py:115: UserWarning: --options is deprecated in favor of --eval-options
#   warnings.warn('--options is deprecated in favor of --eval-options')
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 103/103, 8.2 task/s, elapsed: 13s, ETA:     0s

# %%
# !python ../mmdetection/tools/analysis_tools/custom_coco_analysis.py \
        results_white.bbox.json \
        --ann dataset/different_tests/white_coco.json \
        --areas 1600 4900 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = 0.852
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.890
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = -1.000
# ...

# %%
# !python ../mmdetection/tools/analysis_tools/custom_coco_analysis.py \
        results_white.bbox.json \
        --ann dataset/different_tests/white_coco.json \
        --areas 4900 9216 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.384
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.830
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = 0.830
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.455
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.890
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.929
# ...

# %% [markdown]
# # Red

# %%
# #red
# !python ../mmdetection/tools/test.py job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/red_test.py \
job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth --eval bbox --show
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [                                                  ] 0/75, elapsed: 0s, ETA:Figure(4608.01x3072.01)
# [                                  ] 1/75, 0.3 task/s, elapsed: 3s, ETA:   224sFigure(4608.01x3072.01)
# [                                  ] 2/75, 0.4 task/s, elapsed: 5s, ETA:   178sFigure(4608.01x3072.01)
# [>                                 ] 3/75, 0.4 task/s, elapsed: 7s, ETA:   163sFigure(4608.01x3072.01)
# [>                                 ] 4/75, 0.5 task/s, elapsed: 9s, ETA:   157sFigure(4608.01x3072.01)
# [>>                               ] 5/75, 0.5 task/s, elapsed: 11s, ETA:   152sFigure(4608.01x3072.01)
# [>>                               ] 6/75, 0.5 task/s, elapsed: 13s, ETA:   147sFigure(4608.01x3072.01)
# ...

# %%
# !python ../mmdetection/tools/test.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/red_test.py \
       job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth \
       --format-only \
       --options "jsonfile_prefix=./results_red"
# Out:
# ../mmdetection/tools/test.py:115: UserWarning: --options is deprecated in favor of --eval-options
#   warnings.warn('--options is deprecated in favor of --eval-options')
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# load checkpoint from local path: job4_cascade_rcnn_x101_32x4d_fpn_1x_train_887_map0_5_0_95_aug_PMDistortion_final_fold0/epoch_16.pth
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 75/75, 8.3 task/s, elapsed: 9s, ETA:     0s

# %%
# !python ../mmdetection/tools/analysis_tools/custom_coco_analysis.py \
        results_red.bbox.json \
        --ann dataset/different_tests/red_coco.json \
        --areas 1600 4900 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.059
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = 0.309
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.059
# ...

# %%
# !python ../mmdetection/tools/analysis_tools/custom_coco_analysis.py \
        results_red.bbox.json \
        --ann dataset/different_tests/red_coco.json \
        --areas 4900 9216 10000000000
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.226
#  Average Precision  (AP) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50      | area=medium | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.165
#  Average Recall     (AR) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50      | area= small | maxDets=100 ] = 0.370
# ...
